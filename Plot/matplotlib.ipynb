# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('ggplot')
data=np.random.randn(50)

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', '_classic_test']

# %%
with plt.style.context(('dark_background')):
    plt.plot(np.sin(np.linspace(0,2*np.pi)),'r-o')
plt.show()

# %%
import  matplotlib.pyplot  as  plt 
import  matplotlib.image  as  mpimg 
import  numpy  as  np
# %matplotlib inline

# %%
img=mpimg.imread('stinkbug.png')
print(img)
# Out:
# [[[ 0.40784314  0.40784314  0.40784314]
#   [ 0.40784314  0.40784314  0.40784314]
#   [ 0.40784314  0.40784314  0.40784314]
#   ...,
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]]
#
#  [[ 0.41176471  0.41176471  0.41176471]
#   [ 0.41176471  0.41176471  0.41176471]
#   [ 0.41176471  0.41176471  0.41176471]
#   ...,
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]]
#
#  [[ 0.41960785  0.41960785  0.41960785]
#   [ 0.41568628  0.41568628  0.41568628]
#   [ 0.41568628  0.41568628  0.41568628]
#   ...,
#   [ 0.43137255  0.43137255  0.43137255]
#   [ 0.43137255  0.43137255  0.43137255]
#   [ 0.43137255  0.43137255  0.43137255]]
#
#  ...,
#  [[ 0.43921569  0.43921569  0.43921569]
#   [ 0.43529412  0.43529412  0.43529412]
#   [ 0.43137255  0.43137255  0.43137255]
#   ...,
#   [ 0.45490196  0.45490196  0.45490196]
# ...

# %%
plt.imshow(img)

# %%
lum_img = img[:, :, 0]

# This is array slicing.  You can read more in the `Numpy tutorial
# <https://docs.scipy.org/doc/numpy-dev/user/quickstart.html>`_.

plt.imshow(lum_img)

# %%
plt.imshow(lum_img,cmap='hot')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
implot=plt.imshow(lum_img)
plt.colorbar()
plt.show()

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
plt.show()

# %%
imgplot = plt.imshow(lum_img, clim=(0.0, 0.7))
plt.show()

# %%
fig = plt.figure()
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(lum_img)
a.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
a = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(lum_img)
imgplot.set_clim(0.0, 0.7)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
plt.show()

# %%
from PIL import Image

img = Image.open('stinkbug.png')
img.thumbnail((64, 64), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img)
plt.show()

# %%
imgplot = plt.imshow(img, interpolation="nearest")

# %%
imgplot = plt.imshow(img, interpolation="bicubic")

# %% [markdown]
# # 使用指南

# %%
# sphinx_gallery_thumbnail_number = 3
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 一个图的部件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Figure

# %% [markdown]
# 在整个figure。这个人物跟踪所有的孩子Axes，一些“特殊”艺术家（标题，图例等）和画布。（不要太担心画布，这是至关重要的，因为它实际上是绘画的目标，让你的plot，但作为用户是或多或少看不见你）。一个figure可以有任意数量Axes，但要有用，至少应该有一个。

# %% [markdown]
# 创建一个新的figure最简单的方法是与pyplot：

# %%
fig=plt.figure()
fig.suptitle('No axes on this figure')
fig,ax_lst=plt.subplots(2,2)
plt.show()

# %% [markdown]
# ### Axes

# %% [markdown]
# 这就是你所说的“a plot”，它是具有数据空间的图像区域。一个给定的Figure可以包含许多Axes，但是一个给定的Axes 对象只能是一个Figure。Axes包含两个（或三个3D） Axis对象（注意Axes和Axis之间的区别），它们负责处理数据限制（数据限制也可以通过set_xlim()和 set_ylim方法设置来控制 ）。每个Axes都有一个标题（通过set_title设置 ），一个x标签（通过set_label设置 ）和一个y标签(通过set_ylabel设置 ）。

# %% [markdown]
# ### Axis

# %% [markdown]
# 这些是number-line-like的对象。他们负责设置图形限制并生成ticks（轴上的标记）和ticklabels （标记ticks的字符串）。ticks的位置由一个Locator对象决定， ticklabel字符串由a格式化Formatter。正确的组合，提供非常好的控制滴答位置和标签。

# %% [markdown]
# ### Artist

# %% [markdown]
# 基本上你可以在图中看到的一切是一个艺术家（甚至 Figure，Axes和Axis对象）。这包括Text对象，Line2D对象， collection对象，Patch对象...（你明白了）。当图形被渲染时，所有的艺术家都被绘制到画布上。大多数艺术家被绑在一个轴上; 这样的艺术家不能被多个轴共享，或者从一个移动到另一个。

# %% [markdown]
# ## 绘制函数的输入类型

# %%
import pandas as pd

# %%
a = pd.DataFrame(np.random.rand(4,5), columns = list('abcde'))
a_asndarray = a.values

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)

# %% [markdown]
# ### Matplotlib，pyplot和pylab：它们是如何相关的？

# %% [markdown]
# Matplotlib是整个包装; matplotlib.pyplot 是matplotlib中的一个模块; 并且pylab是一个安装在一起的模块matplotlib。
#
# Pyplot为底层的面向对象的绘图库提供状态机界面。状态机隐式地自动创建数字和坐标轴以实现所需的绘图。例如：

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# 首先调用plt.plot会自动创建必要的图形和坐标轴以实现所需的绘图。随后的调用 plt.plot重新使用当前的轴，每个添加另一条线。设置标题，图例和轴标签也会自动使用当前轴，并设置标题，创建图例，并分别标注轴。
#
# pylab是一个便利的模块，可以 在单个名称空间中批量导入 matplotlib.pyplot（用于绘图）和numpy（用于数学和使用数组）。虽然有很多例子使用pylab，但不再推荐。
#
# 对于非交互式绘图，建议使用pyplot创建图形，然后使用OO界面进行绘图。

# %% [markdown]
# ## 编码风格

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)
plt.show()

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# which you would then use as:

data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %% [markdown]
# ## 后端

# %% [markdown]
# ### 什么是后端？

# %% [markdown]
# 网站上和邮件列表上的很多文档都提到了“后端”，许多新用户对这个术语感到困惑。matplotlib针对许多不同的用例和输出格式。有些人从python shell交互地使用matplotlib，并且在输入命令时弹出绘图窗口。有些人将matplotlib嵌入图形用户界面（如wxpython或pygtk）来构建丰富的应用程序。其他人在批处理脚本中使用matplotlib来从一些数字模拟中生成postscript图像，还有一些在web应用程序服务器中动态提供图形。
#
# 为了支持所有这些用例，matplotlib可以定位不同的输出，并且这些功能中的每一个被称为后端; “前端”是面向用户的代码，也就是绘图代码，而“后端”是做所有的努力工作的幕后人物。有两种类型的后端：用户界面后端（用于pygtk，wxpython，tkinter，qt4或macosx;也被称为“交互式后端”）和硬拷贝后端来制作图像文件（PNG，SVG，PDF，PS;也被称为“非交互式后端”）。
#
# 有四种方法来配置您的后端。如果它们相互冲突，将使用以下列表中最后提到的方法，例如，调用 use()将覆盖您的设置matplotlibrc。

# %% [markdown]
# 1.文件中的backend参数matplotlibrc（请参阅 定制matplotlib）：

# %% [markdown]
# # Pyplot教程

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])#设置X轴，Y轴范围
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ### 用关键字字符串绘图

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ### 用分类变量绘图

# %%
names = [1,2,3]
values = [1, 10, 100]

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ### 控制线特性

# %% [markdown]
# 线条有许多可以设置的属性：线宽，短划线样式，反锯齿等; 看[matplotlib.lines.Line2D](http://matplotlib.org/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D)。有几种方法来设置线条属性

# %% [markdown]
# - 使用关键字参数：

# %%
plt.plot(x, y, linewidth=2.0)

# %% [markdown]
# - 使用Line2D实例的setter方法。 plot返回一个Line2D对象列表;

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False) # turn off antialising

# %% [markdown]
# - 使用该setp()命令。下面的例子使用MATLAB风格的命令在行列表上设置多个属性。 setp透明地与对象列表或单个对象一起工作。你可以使用python关键字参数或MATLAB风格的字符串/值对：

# %%
x1=y1=np.arange(50)
x2=y2=np.arange(40)
lines = plt.plot(x1, y1, x2, y2)
# use keyword args
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# [None, None, None, None]

# %%
lines = plt.plot([1, 2, 3])

# %% [markdown]
# 这里是可用的Line2D属性。

# %% [markdown]
# 属性|值类型
# :----|:----
# alpha	|float
# animated	|[True / False]
# antialiased or aa |	[True / False]
# clip_box	|a matplotlib.transform.Bbox instance
# clip_on|	[True / False]
# clip_path	|a Path instance and a Transform instance, a Patch
# color or c	|any matplotlib color
# contains	|the hit testing function
# dash_capstyle|	['butt' / 'round' / 'projecting']
# dash_joinstyle	|['miter' / 'round' / 'bevel']
# dashes	|sequence of on/off ink in points
# data	|(np.array xdata, np.array ydata)
# figure	|a matplotlib.figure.Figure instance
# label	|any string
# linestyle or ls	|[ '-' / '--' / '-.' / ':' / 'steps' / …]
# linewidth or lw|	float value in points
# lod	|[True / False]
# marker	|[ '+' / ',' / '.' / '1' / '2' / '3' / '4' ]
# markeredgecolor or mec|	any matplotlib color
# markeredgewidth or mew	|float value in points
# markerfacecolor or mfc	|any matplotlib color
# markersize or ms|	float
# markevery	|[ None / integer / (startind, stride) ]
# picker	|used in interactive line selection
# pickradius	|the line pick selection radius
# solid_capstyle|['butt' / 'round' / 'projecting']
# solid_joinstyle	|['miter' / 'round' / 'bevel']
# transform	|a matplotlib.transforms.Transform instance
# visible|	[True / False]
# xdata	|np.array
# ydata	|np.array
# zorder	|any number

# %% [markdown]
# 要获取可设置的行属性的列表，请setp()使用一行或多行作为参数来调用该 函数

# %%
plt.setp(lines)
# Out:
#   agg_filter: unknown
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: [True | False]
#   antialiased or aa: [True | False]
#   axes: an :class:`~matplotlib.axes.Axes` instance
#   clip_box: a :class:`matplotlib.transforms.Bbox` instance
#   clip_on: [True | False]
#   clip_path: [ (:class:`~matplotlib.path.Path`, :class:`~matplotlib.transforms.Transform`) | :class:`~matplotlib.patches.Patch` | None ]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' | 'steps-post']
#   figure: a :class:`matplotlib.figure.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: string or anything printable with '%s' conversion.
# ...

# %% [markdown]
# ## 与多种图形和轴工作

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title

plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## 对数和其他非线性轴
# matplotlib.pyplot不仅支持线性轴比例尺，还支持对数和对数尺度。如果数据跨越很多数量级，这就是常用的。改变轴的尺寸很简单：
# `plt.xscale(‘log’)`

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# # The Lifecycle of a Plot

# %% [markdown]
# ## 关于面向对象API和Pyplot的注释

# %% [markdown]
# Matplotlib有两个接口。第一个是面向对象（OO）接口。在这种情况下，我们利用一个实例axes.Axes 来渲染一个实例的可视化figure.Figure。
#
# 第二个是基于MATLAB并使用基于状态的接口。这被封装在pyplot 模块中。请参阅pyplot教程 以更深入地了解pyplot接口。
#
# 大部分条款都很简单，但要记住的主要是：
#
# - 该图是可能包含一个或多个轴的最终图像。
# - 轴代表一个单独的情节（不要把它与“轴”这个词相提并论，它是指一个情节的x / y轴）。
#
# 我们称之为直接从轴心绘图的方法，这使我们在定制我们的绘图时有更多的灵活性和能力。有关如何使用此方法的许多示例，请参阅 面向对象的示例。

# %% [markdown]
# **注意:**
# 通常，尝试通过pyplot接口使用面向对象的接口。

# %%
# sphinx_gallery_thumbnail_number = 10
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %% [markdown]
# ## 入门

# %% [markdown]
# 这些数据自然可视化为一个barplot，每个组有一个bar。为了与面向对象的方法做到这一点，我们首先产生的一个实例figure.Figure和 axes.Axes。这个图像就像一个画布，而Axes是我们将在其中进行特定可视化的画布的一部分。

# %% [markdown]
# 注意
# 数字可以有多个轴

# %%
fig, ax = plt.subplots()

# %% [markdown]
# 现在我们有一个Axes实例，我们可以在它上面绘图。

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
plt.show()

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', '_classic_test']

# %%
plt.style.use('classic')

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
plt.show()

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
plt.show()

# %%
plt.style.use('seaborn-dark')

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
labels = ax.get_xticklabels()
# 设置标签
plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
# 我们将使用xaxis我们轴的属性。这使您可以在我们的图上的特定轴上执行操作。
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))#设置图形大小
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
# 我们将使用xaxis我们轴的属性。这使您可以在我们的图上的特定轴上执行操作。
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()

# %%
# 对于标签，我们可以通过使用ticker.FuncFormatter类来以函数的形式指定自定义的格式指导。
#下面我们将定义一个函数，它将一个整数作为输入，并返回一个字符串作为输出。
def currency(x, pos):
    """The two args are the value and tick position"""
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s

formatter = FuncFormatter(currency)

# %%
fig, ax = plt.subplots(figsize=(6, 8))
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')# 我们将使用xaxis我们轴的属性。这使您可以在我们的图上的特定轴上执行操作。
ax.xaxis.set_major_formatter(formatter)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(200, 8))
ax.barh(range(len(group_data)), group_data)
plt.yticks(range(len(group_data)), group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

# 添加一条垂直线，在这里我们用函数call 设置
ax.axvline(group_mean, ls='--', color='r')

# 注释新公司
for group in [3, 5, 8]:
    ax.text(145000, group, "New Company", fontsize=10,
            verticalalignment="center")

# 现在我们会把它的标题向上移动，因为它有一个点挤
ax.title.set(y=1.05)

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)
ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
fig.subplots_adjust(right=.1)

plt.show()

# %% [markdown]
# ## 保存我们的图片

# %% [markdown]
# 现在我们对olot的结果感到满意，我们想把它保存到磁盘。我们可以在Matplotlib中保存很多文件格式。要查看可用选项的列表，请使用：

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'ps': 'Postscript', 'eps': 'Encapsulated Postscript', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format'}

# %%
#fig.savefig（'sales.png'，transparent = False，dpi = 80，bbox_inches =“tight”） #保存图片的语法
